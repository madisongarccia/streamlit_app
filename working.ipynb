# %%
pip install uszipcode
# Out:
# Collecting uszipcode
#   Downloading uszipcode-1.0.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: attrs in /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages (from uszipcode) (23.1.0)
# Requirement already satisfied: requests in /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages (from uszipcode) (2.31.0)
# Collecting pathlib-mate (from uszipcode)
#   Downloading pathlib_mate-1.3.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting atomicwrites (from uszipcode)
#   Using cached atomicwrites-1.4.1-py2.py3-none-any.whl
# Collecting fuzzywuzzy (from uszipcode)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting haversine>=2.5.0 (from uszipcode)
#   Downloading haversine-2.8.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting SQLAlchemy>=1.4.0 (from uszipcode)
#   Downloading SQLAlchemy-2.0.29-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting sqlalchemy-mate>=1.4.28.3 (from uszipcode)
#   Downloading sqlalchemy_mate-1.4.28.4-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages (from SQLAlchemy>=1.4.0->uszipcode) (4.9.0)
# Collecting SQLAlchemy>=1.4.0 (from uszipcode)
#   Downloading SQLAlchemy-1.4.52-cp311-cp311-macosx_10_9_universal2.whl.metadata (10 kB)
# Collecting prettytable (from sqlalchemy-mate>=1.4.28.3->uszipcode)
#   Downloading prettytable-3.10.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages (from requests->uszipcode) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages (from requests->uszipcode) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages (from requests->uszipcode) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages (from requests->uszipcode) (2023.11.17)
# Requirement already satisfied: wcwidth in /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages (from prettytable->sqlalchemy-mate>=1.4.28.3->uszipcode) (0.2.5)
# Downloading uszipcode-1.0.1-py2.py3-none-any.whl (35 kB)
# Downloading haversine-2.8.1-py2.py3-none-any.whl (7.7 kB)
# Downloading sqlalchemy_mate-1.4.28.4-py2.py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.5 MB/s eta 0:00:00
# Downloading SQLAlchemy-1.4.52-cp311-cp311-macosx_10_9_universal2.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.6 MB/s eta 0:00:0000:0100:01
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Downloading pathlib_mate-1.3.2-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.9 MB/s eta 0:00:00
# Downloading prettytable-3.10.0-py3-none-any.whl (28 kB)
# Installing collected packages: fuzzywuzzy, SQLAlchemy, prettytable, pathlib-mate, haversine, atomicwrites, sqlalchemy-mate, uszipcode
# Successfully installed SQLAlchemy-1.4.52 atomicwrites-1.4.1 fuzzywuzzy-0.18.0 haversine-2.8.1 pathlib-mate-1.3.2 prettytable-3.10.0 sqlalchemy-mate-1.4.28.4 uszipcode-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import folium
import geopy
from geopy.geocoders import Nominatim
from uszipcode import SearchEngine
# Out:
# /Users/madisonwozniak/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning:
#
# Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning

# %%
data = {
    'City': ['Los Angeles', 'San Diego', 'Santa Barbara', 'Long Beach']
}

df = pd.DataFrame(data)

# Create a folium map centered around Southern California
map_sc = folium.Map(location=[34.052235, -118.243683], zoom_start=7)

# Initialize Nominatim geocoder
geolocator = Nominatim(user_agent="southern_california")

# Add markers for each city
for index, row in df.iterrows():
    location = geolocator.geocode(row['City'] + ", Southern California")
    if location:
        folium.Marker(location=[location.latitude, location.longitude], popup=row['City']).add_to(map_sc)

# Display the map
map_sc.save('southern_california_cities_geocoded.html')
map_sc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18fa04c930ae568fc496a22efbcfa8bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18fa04c930ae568fc496a22efbcfa8bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18fa04c930ae568fc496a22efbcfa8bf = L.map(
#                 &quot;map_18fa04c930ae568fc496a22efbcfa8bf&quot;,
#                 {
#                     center: [34.052235, -118.243683],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e1219e8196d28c7ff34144a73fdbb5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8e1219e8196d28c7ff34144a73fdbb5a.addTo(map_18fa04c930ae568fc496a22efbcfa8bf);
#
#
#             var marker_16dc24b19c155394d9742b8b9d7049b9 = L.marker(
#                 [33.9510011, -118.2062682],
#                 {}
#             ).addTo(map_18fa04c930ae568fc496a22efbcfa8bf);
#
#
#         var popup_21d905e53ed9e6773db12d93943d8c3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_664f2e680312d96d8bd2df70b37702ae = $(`&lt;div id=&quot;html_664f2e680312d96d8bd2df70b37702ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_21d905e53ed9e6773db12d93943d8c3a.setContent(html_664f2e680312d96d8bd2df70b37702ae);
#
#
#
#         marker_16dc24b19c155394d9742b8b9d7049b9.bindPopup(popup_21d905e53ed9e6773db12d93943d8c3a)
#         ;
#
#
#
#
#             var marker_0a471f18e71211e2f2d09d7faab8a6f3 = L.marker(
#                 [33.3700231, -117.0800179],
#                 {}
#             ).addTo(map_18fa04c930ae568fc496a22efbcfa8bf);
#
#
#         var popup_0a273501384bba33472670822c937de2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ee1929856f710dce3a280c2c805b020 = $(`&lt;div id=&quot;html_0ee1929856f710dce3a280c2c805b020&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Diego&lt;/div&gt;`)[0];
#                 popup_0a273501384bba33472670822c937de2.setContent(html_0ee1929856f710dce3a280c2c805b020);
#
#
#
#         marker_0a471f18e71211e2f2d09d7faab8a6f3.bindPopup(popup_0a273501384bba33472670822c937de2)
#         ;
#
#
#
#
#             tile_layer_8e1219e8196d28c7ff34144a73fdbb5a.addTo(map_18fa04c930ae568fc496a22efbcfa8bf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_sc = folium.Map(location=[34.052235, -118.243683], zoom_start=7)
geolocator = Nominatim(user_agent="southern_california")
cities = data['City']
la_city_coordinates = {
    'Los Angeles': (34.052235, -118.243683),
    'Long Beach': (33.770050, -118.193740),
    'Santa Monica': (34.0194, -118.4912),
    'Beverly Hills': (34.0736, -118.4004),
    'Pasadena': (34.1478, -118.1445),
    'Glendale': (34.1425, -118.2551),
    'Santa Clarita': (34.3917, -118.5426),
    'Torrance': (33.8350, -118.3406),
    'Inglewood': (33.9617, -118.3531),
    'Downey': (33.9400, -118.1336),
    'Norwalk': (33.9022, -118.0817),
    'Compton': (33.8958, -118.2201),
    'Pomona': (34.0551, -117.7499),
    'West Hollywood': (34.0900, -118.3617),
    'Lakewood': (33.8506, -118.1332),
    'Whittier': (33.9792, -118.0328),
    'Burbank': (34.1808, -118.3089),
    'Redondo Beach': (33.8492, -118.3884),
    'Huntington Beach': (33.6603, -117.9992),
    'Anaheim': (33.8366, -117.9143),
    'El Segundo': (33.9192, -118.4165),
    'Culver City': (34.0211, -118.3965),
    'Hawthorne': (33.9164, -118.3526)
}
for city in cities:
    if isinstance(city, str):
        city = city.strip('\n, ')
        if city in la_city_coordinates:
            folium.Marker(location=la_city_coordinates[city], popup=city).add_to(map_sc)
        else:
            #print(f'city: {city}')
            location = geolocator.geocode(city + ', Southern California')
            if location:
                folium.Marker(location=[location.latitude, location.longitude], popup=row['City']).add_to(map_sc)

map_sc.save('southern_california_cities_geocoded.html')
map_sc
# Out:
# city: Los Angeles County
# city: Manhattan Beach
# city: Venice
# city: Los Angeles County
# city: Carson
# city: Van Nuys
# city: Gardena
# city: Commerce
# city: Venice
# city: Commerce
# city: Venice
# city: Lomita
# city: Alhambra
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9420e424442b2bf76e757f93c241232 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9420e424442b2bf76e757f93c241232&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9420e424442b2bf76e757f93c241232 = L.map(
#                 &quot;map_c9420e424442b2bf76e757f93c241232&quot;,
#                 {
#                     center: [34.052235, -118.243683],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82ac937f15ec2c65f84bf97e8f52f2e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_82ac937f15ec2c65f84bf97e8f52f2e2.addTo(map_c9420e424442b2bf76e757f93c241232);
#
#
#             var marker_64b8cb4b84b4d5a5516085e2ce3f48e0 = L.marker(
#                 [34.052235, -118.243683],
#                 {}
#             ).addTo(map_c9420e424442b2bf76e757f93c241232);
#
#
#         var popup_9ce1a806962d44611c9e050cd11996f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d42582152280f7342505db0b83f60ea = $(`&lt;div id=&quot;html_1d42582152280f7342505db0b83f60ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_9ce1a806962d44611c9e050cd11996f9.setContent(html_1d42582152280f7342505db0b83f60ea);
#
#
#
#         marker_64b8cb4b84b4d5a5516085e2ce3f48e0.bindPopup(popup_9ce1a806962d44611c9e050cd11996f9)
#         ;
#
#
#
#
#             var marker_c94bf4247a5f5f690e999a4e643d30d6 = L.marker(
#                 [34.052235, -118.243683],
#                 {}
#             ).addTo(map_c9420e424442b2bf76e757f93c241232);
#
#
#         var popup_9d3395bb4f6d8a9d85a28a965e482895 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_589bc00b4ebd37d60f1a904cde0f4b27 = $(`&lt;div id=&quot;html_589bc00b4ebd37d60f1a904cde0f4b27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_9d3395bb4f6d8a9d85a28a965e482895.setContent(html_589bc00b4ebd37d60f1a904cde0f4b27);
#
#
#
#         marker_c94bf4247a5f5f690e999a4e643d30d6.bindPopup(popup_9d3395bb4f6d8a9d85a28a965e482895)
#         ;
#
#
#
#
#             var marker_447bb9352547abbbf51d16b51d9f82e2 = L.marker(
#                 [34.052235, -118.243683],
#                 {}
#             ).addTo(map_c9420e424442b2bf76e757f93c241232);
#
#
#         var popup_3f4bfe6dd737b956f482ab0ba2e2aec7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c0f1ad369c57562f8a2c2f0bc3cc780 = $(`&lt;div id=&quot;html_8c0f1ad369c57562f8a2c2f0bc3cc780&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_3f4bfe6dd737b956f482ab0ba2e2aec7.setContent(html_8c0f1ad369c57562f8a2c2f0bc3cc780);
#
#
#
#         marker_447bb9352547abbbf51d16b51d9f82e2.bindPopup(popup_3f4bfe6dd737b956f482ab0ba2e2aec7)
#         ;
#
#
#
#
#             var marker_b0a2e6887f8b86170f8fdb96cb44d884 = L.marker(
#                 [34.052235, -118.243683],
#                 {}
#             ).addTo(map_c9420e424442b2bf76e757f93c241232);
#
#
#         var popup_65297e6152b0ab002d47b2dc60a7f3fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29e5001c8b40189e1bd21765cad9f13a = $(`&lt;div id=&quot;html_29e5001c8b40189e1bd21765cad9f13a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Los Angeles&lt;/div&gt;`)[0];
#                 popup_65297e6152b0ab002d47b2dc60a7f3fb.setContent(html_29e5001c8b40189e1bd21765cad9f13a);
#
#
#
#         marker_b0a2e6887f8b86170f8fdb96cb44d884.bindPopup(popup_65297e6152b0ab002d47b2dc60a7f3fb)
#         ;
#
#
#
#
#             var marker_42385675bd2850c53dc53c215b61e00e = L.marker(
#                 [34.1478, -118.1445],
#                 {}
#             ).addTo(map_c9420e424442b2bf76e757f93c241232);
#
#
#         var popup_f449ab4704a270858b9e9e7434ed6359 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85613d13f66c5f3a46641cc451f3ab0e = $(`&lt;div id=&quot;html_85613d13f66c5f3a46641cc451f3ab0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pasadena&lt;/div&gt;`)[0];
#                 popup_f449ab4704a270858b9e9e7434ed6359.setContent(html_85613d13f66c5f3a46641cc451f3ab0e);
#
#
#
#         marker_42385675bd2850c53dc53c215b61e00e.bindPopup(popup_f449ab4704a270858b9e9e7434ed6359)
#         ;
#
#
#
#
#             var marker_409ee6019a118878286a8f045da7bf0f = L.marker(
#                 [34.1808, -118.3089],
#                 {}
#             ).addTo(map_c9420e424442b2bf76e757f93c241232);

# %%
map_sc = folium.Map(location=[34.052235, -118.243683], zoom_start=7)
geolocator = Nominatim(user_agent="southern_california")
cities = data['City']
city_coordinates = {}
def get_coordinates(city):
    search = SearchEngine()
    result = search.by_city(city, returns=1)
    if result:
        return (result[0].lat, result[0].lng)
    else:
        return None
for city in cities:
    if isinstance(city, str):
        coordinates = get_coordinates(city)
        if coordinates:
            city_coordinates[city] = coordinates

print(city_coordinates)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/process.py:108, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     106 try:
#     107     # See if choices is a dictionary-like object.
# --> 108     for key, choice in choices.items():
#     109         processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 14
#      12 for city in cities:
#      13     if isinstance(city, str):
# ---> 14         coordinates = get_coordinates(city)
#      15         if coordinates:
#      16             city_coordinates[city] = coordinates
#
# Cell In[39], line 7, in get_coordinates(city)
#       5 def get_coordinates(city):
#       6     search = SearchEngine()
# ----> 7     result = search.by_city(city, returns=1)
#       8     if result:
#       9         return (result[0].lat, result[0].lng)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/uszipcode/search.py:763, in SearchEngine.by_city(self, city, zipcode_type, sort_by, ascending, returns)
#     750 def by_city(
#     751     self,
#     752     city: str,
#    (...)
#     756     returns: int = DEFAULT_LIMIT,
#     757 ):
#     758     """
#     759     Search zipcode information by fuzzy City name.
#     760
#     761     My engine use fuzzy match and guess what is the city you want.
#     762     """
# --> 763     return self.query(
#     764         city=city,
#     765         sort_by=sort_by, zipcode_type=zipcode_type,
#     766         ascending=ascending, returns=returns,
#     767     )
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/uszipcode/search.py:554, in SearchEngine.query(self, zipcode, prefix, pattern, city, state, lat, lng, radius, population_lower, population_upper, population_density_lower, population_density_upper, land_area_in_sqmi_lower, land_area_in_sqmi_upper, water_area_in_sqmi_lower, water_area_in_sqmi_upper, housing_units_lower, housing_units_upper, occupied_housing_units_lower, occupied_housing_units_upper, median_home_value_lower, median_home_value_upper, median_household_income_lower, median_household_income_upper, zipcode_type, sort_by, ascending, returns)
#     552 elif (city is not None):
#     553     try:
# --> 554         city = self.find_city(city, None, best_match=True)[0]
#     555         filters.append(self.zip_klass.major_city == city)
#     556     except ValueError:  # pragma: no cover
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/uszipcode/search.py:370, in SearchEngine.find_city(self, city, state, best_match, min_similarity)
#     367 result_city_list = list()
#     369 if best_match:
# --> 370     city, confidence = extractOne(city, city_pool)
#     371     if confidence >= min_similarity:
#     372         result_city_list.append(city)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/process.py:220, in extractOne(query, choices, processor, scorer, score_cutoff)
#     218 best_list = extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     219 try:
# --> 220     return max(best_list, key=lambda i: i[1])
#     221 except ValueError:
#     222     return None
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/process.py:117, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     115 for choice in choices:
#     116     processed = pre_processor(processor(choice))
# --> 117     score = scorer(processed_query, processed)
#     118     if score >= score_cutoff:
#     119         yield (choice, score)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:297, in WRatio(s1, s2, force_ascii, full_process)
#     295 else:
#     296     tsor = token_sort_ratio(p1, p2, full_process=False) * unbase_scale
# --> 297     tser = token_set_ratio(p1, p2, full_process=False) * unbase_scale
#     299     return utils.intr(max(base, tsor, tser))
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:169, in token_set_ratio(s1, s2, force_ascii, full_process)
#     168 def token_set_ratio(s1, s2, force_ascii=True, full_process=True):
# --> 169     return _token_set(s1, s2, partial=False, force_ascii=force_ascii, full_process=full_process)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/utils.py:38, in check_for_none.<locals>.decorator(*args, **kwargs)
#      36 if args[0] is None or args[1] is None:
#      37     return 0
# ---> 38 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:163, in _token_set(s1, s2, partial, force_ascii, full_process)
#     157 else:
#     158     ratio_func = ratio
#     160 pairwise = [
#     161     ratio_func(sorted_sect, combined_1to2),
#     162     ratio_func(sorted_sect, combined_2to1),
# --> 163     ratio_func(combined_1to2, combined_2to1)
#     164 ]
#     165 return max(pairwise)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/utils.py:38, in check_for_none.<locals>.decorator(*args, **kwargs)
#      36 if args[0] is None or args[1] is None:
#      37     return 0
# ---> 38 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/utils.py:29, in check_for_equivalence.<locals>.decorator(*args, **kwargs)
#      27 if args[0] == args[1]:
#      28     return 100
# ---> 29 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/utils.py:47, in check_empty_string.<locals>.decorator(*args, **kwargs)
#      45 if len(args[0]) == 0 or len(args[1]) == 0:
#      46     return 0
# ---> 47 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/stat386/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:28, in ratio(s1, s2)
#      25 s1, s2 = utils.make_type_consistent(s1, s2)
#      27 m = SequenceMatcher(None, s1, s2)
# ---> 28 return utils.intr(100 * m.ratio())
#
# File ~/miniconda3/envs/stat386/lib/python3.11/difflib.py:619, in SequenceMatcher.ratio(self)
#     597 def ratio(self):
#     598     """Return a measure of the sequences' similarity (float in [0,1]).
#     599
#     600     Where T is the total number of elements in both sequences, and
#    (...)
#     616     1.0
#     617     """
# --> 619     matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620     return _calculate_ratio(matches, len(self.a) + len(self.b))
#
# File ~/miniconda3/envs/stat386/lib/python3.11/difflib.py:454, in SequenceMatcher.get_matching_blocks(self)
#     452 while queue:
#     453     alo, ahi, blo, bhi = queue.pop()
# --> 454     i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     455     # a[alo:i] vs b[blo:j] unknown
#     456     # a[i:i+k] same as b[j:j+k]
#     457     # a[i+k:ahi] vs b[j+k:bhi] unknown
#     458     if k:   # if k is 0, there was no matching block
#
# File ~/miniconda3/envs/stat386/lib/python3.11/difflib.py:399, in SequenceMatcher.find_longest_match(self, alo, ahi, blo, bhi)
#     394 while besti > alo and bestj > blo and \
#     395       not isbjunk(b[bestj-1]) and \
#     396       a[besti-1] == b[bestj-1]:
#     397     besti, bestj, bestsize = besti-1, bestj-1, bestsize+1
#     398 while besti+bestsize < ahi and bestj+bestsize < bhi and \
# --> 399       not isbjunk(b[bestj+bestsize]) and \
#     400       a[besti+bestsize] == b[bestj+bestsize]:
#     401     bestsize += 1
#     403 # Now that we have a wholly interesting match (albeit possibly
#     404 # empty!), we may as well suck up the matching junk on each
#     405 # side of it too.  Can't think of a good reason not to, and it
#    (...)
#     408 # interesting match, this is clearly the right thing to do,
#     409 # because no other kind of match is possible in the regions.
#
# KeyboardInterrupt:
